# %% [markdown]
# ### Installation

# %% [markdown]
# `conda install brockman-pipeline`

# %% [markdown]
# `conda install ruby amused bedtools ucsc-twobittofa samtools trimmomatic r-jackstraw r-ggplot2 r-tsne -y`

# %% [markdown]
# `install.packages("devtools")`
# `library(devtools)`
# `install_github("Carldeboer/BrockmanR")`

# %% [markdown]
# ### Import packages

# %%
library(BrockmanR)
library(irlba)
# Out:
# Loading required package: ggplot2
# Loading required package: tsne
# Loading required package: Matrix

# %% [markdown]
# ### Preprocess

# %%
chrom_size = read.table('../../input/hg19/hg19.chrom.sizes')
head(chrom_size)
chrom_size$V3 <- rep(0,dim(chrom_size)[1])
head(chrom_size)
chromBED <- chrom_size[, c("V1", "V3", "V2")]
head(chromBED)
# Out:
#   V1   V2
# 1 chr1 249250621
# 2 chr2 243199373
# 3 chr3 198022430
# 4 chr4 191154276
# 5 chr5 180915260
# 6 chr6 171115067
#   V1   V2        V3
# 1 chr1 249250621 0
# 2 chr2 243199373 0
# 3 chr3 198022430 0
# 4 chr4 191154276 0
# 5 chr5 180915260 0
# 6 chr6 171115067 0
#   V1   V3 V2
# 1 chr1 0  249250621
# 2 chr2 0  243199373
# 3 chr3 0  198022430
# 4 chr4 0  191154276
# 5 chr5 0  180915260
# 6 chr6 0  171115067

# %%
# write.table(file = 'chroms.bed', chromBED,col.names = FALSE,row.names = FALSE,quote = FALSE,sep="\t")

# %%
bamfile <- list.files(path = "../../input/sc-bams_nodup/",pattern = "\\.bam$")
length(bamfile)
# Out:
# [1] 5335

# %%
path_to_bamfile <- paste0("../../../../input/sc-bams_nodup/",bamfile)
cellnames <- sapply(strsplit(bamfile,'.',fixed = TRUE), "[[", 2)
sample_list_bam <- cbind(cellnames,path_to_bamfile)
head(sample_list_bam)
# write.table(file = './Brockman-master/Example/sample_list_bam.txt', sample_list_bam,col.names = FALSE,row.names = FALSE,quote = FALSE,sep="\t")
# Out:
#      cellnames
# [1,] AAACGAAAGCGCAATG-1
# [2,] AAACGAAAGGGTATCG-1
# [3,] AAACGAAAGTAACATG-1
# [4,] AAACGAAAGTTACACC-1
# [5,] AAACGAACAGAGATGC-1
# [6,] AAACGAACATGCTATG-1
#      path_to_bamfile
# [1,] ../../../../input/sc-bams_nodup/atac_v1_pbmc_5k_possorted_bam.AAACGAAAGCGCAATG-1.dedup.st.bam
# [2,] ../../../../input/sc-bams_nodup/atac_v1_pbmc_5k_possorted_bam.AAACGAAAGGGTATCG-1.dedup.st.bam
# [3,] ../../../../input/sc-bams_nodup/atac_v1_pbmc_5k_possorted_bam.AAACGAAAGTAACATG-1.dedup.st.bam
# [4,] ../../../../input/sc-bams_nodup/atac_v1_pbmc_5k_possorted_bam.AAACGAAAGTTACACC-1.dedup.st.bam
# [5,] ../../../../input/sc-bams_nodup/atac_v1_pbmc_5k_possorted_bam.AAACGAACAGAGATGC-1.dedup.st.bam
# [6,] ../../../../input/sc-bams_nodup/atac_v1_pbmc_5k_possorted_bam.AAACGAACATGCTATG-1.dedup.st.bam

# %%
elbow_plot <- function(mat,num_pcs=50,scale=FALSE,center=FALSE,title='',width=3,height=3){
    set.seed(2019) 
    mat = data.matrix(mat)
    SVD = irlba(mat, num_pcs, num_pcs,scale=scale,center=center)
    options(repr.plot.width=width, repr.plot.height=height)
    df_plot = data.frame(PC=1:num_pcs, SD=SVD$d);
#     print(SVD$d[1:num_pcs])
    p <- ggplot(df_plot, aes(x = PC, y = SD)) +
      geom_point(col="#cd5c5c",size = 1) + 
      ggtitle(title)
    return(p)
}

# %% [markdown]
# ### Obtain Feature Matrix

# %% [markdown]
# `bsub < example_run_pipeine_LSF.sh`

# %%
start_time <- Sys.time()

# %%
metadata <- read.table('../../input/metadata.tsv',
                         header = TRUE,
                         stringsAsFactors=FALSE,quote="",row.names=1)

# %%
sampleDesc <- metadata

# %%
allData = BrockmanR::inputKMerFreqs(
    fileNames = sprintf("./Brockman-master/Example/kmer_frequencies/%s.freq.gz",
                        rownames(metadata)), 
    IDs = rownames(metadata))
# Out:
# Inputting i=1/5335
# Inputting i=51/5335
# Inputting i=101/5335
# Inputting i=151/5335
# Inputting i=201/5335
# Inputting i=251/5335
# Inputting i=301/5335
# Inputting i=351/5335
# Inputting i=401/5335
# Inputting i=451/5335
# Inputting i=501/5335
# Inputting i=551/5335
# Inputting i=601/5335
# Inputting i=651/5335
# Inputting i=701/5335
# Inputting i=751/5335
# Inputting i=801/5335
# Inputting i=851/5335
# Inputting i=901/5335
# Inputting i=951/5335
# Inputting i=1001/5335
# Inputting i=1051/5335
# Inputting i=1101/5335
# Inputting i=1151/5335
# Inputting i=1201/5335
# Inputting i=1251/5335
# Inputting i=1301/5335
# Inputting i=1351/5335
# Inputting i=1401/5335
# Inputting i=1451/5335
# Inputting i=1501/5335
# Inputting i=1551/5335
# Inputting i=1601/5335
# Inputting i=1651/5335
# Inputting i=1701/5335
# Inputting i=1751/5335
# Inputting i=1801/5335
# Inputting i=1851/5335
# Inputting i=1901/5335
# Inputting i=1951/5335
# Inputting i=2001/5335
# Inputting i=2051/5335
# Inputting i=2101/5335
# Inputting i=2151/5335
# Inputting i=2201/5335
# Inputting i=2251/5335
# Inputting i=2301/5335
# Inputting i=2351/5335
# Inputting i=2401/5335
# Inputting i=2451/5335
# Inputting i=2501/5335
# Inputting i=2551/5335
# Inputting i=2601/5335
# Inputting i=2651/5335
# Inputting i=2701/5335
# Inputting i=2751/5335
# Inputting i=2801/5335
# Inputting i=2851/5335
# Inputting i=2901/5335
# Inputting i=2951/5335
# Inputting i=3001/5335
# Inputting i=3051/5335
# Inputting i=3101/5335
# Inputting i=3151/5335
# Inputting i=3201/5335
# Inputting i=3251/5335
# Inputting i=3301/5335
# Inputting i=3351/5335
# Inputting i=3401/5335
# Inputting i=3451/5335
# Inputting i=3501/5335
# Inputting i=3551/5335
# Inputting i=3601/5335
# Inputting i=3651/5335
# Inputting i=3701/5335
# Inputting i=3751/5335
# Inputting i=3801/5335
# Inputting i=3851/5335
# Inputting i=3901/5335
# Inputting i=3951/5335
# Inputting i=4001/5335
# Inputting i=4051/5335
# Inputting i=4101/5335
# Inputting i=4151/5335
# Inputting i=4201/5335
# Inputting i=4251/5335
# Inputting i=4301/5335
# Inputting i=4351/5335
# Inputting i=4401/5335
# Inputting i=4451/5335
# Inputting i=4501/5335
# Inputting i=4551/5335
# Inputting i=4601/5335
# Inputting i=4651/5335
# Inputting i=4701/5335
# Inputting i=4751/5335
# Inputting i=4801/5335
# Inputting i=4851/5335
# Inputting i=4901/5335
# Inputting i=4951/5335
# Inputting i=5001/5335
# Inputting i=5051/5335
# Inputting i=5101/5335
# Inputting i=5151/5335
# Inputting i=5201/5335
# Inputting i=5251/5335
# Inputting i=5301/5335

# %%
allData[1:5,1:5]
# Out:
#          AAACGAAAGCGCAATG-1 AAACGAAAGGGTATCG-1 AAACGAAAGTAACATG-1
# TTTTAAAA 0.0071736772       0.0080114138       0.0077803947
# TTTGCAAA 0.0026857117       0.0028478072       0.0024439856
# TTTGAAAA 0.0029684182       0.0034580516       0.0035426581
# TTTCGAAA 0.0007774428       0.0007823646       0.0005157034
# TTTCCAAA 0.0029860873       0.0030981639       0.0025224622
#          AAACGAAAGTTACACC-1 AAACGAACAGAGATGC-1
# TTTTAAAA 0.0070400627       0.0067546139
# TTTGCAAA 0.0021167756       0.0026375159
# TTTGAAAA 0.0030324594       0.0028626697
# TTTCGAAA 0.0005708159       0.0007719559
# TTTCCAAA 0.0023427236       0.0027661752

# %%
p_elbow_BROCKMAN <- elbow_plot(allData,num_pcs = 30, title = 'PCA on BROCKMAN')
p_elbow_BROCKMAN
# Out:
# plot without title

# %%
pcs = doKMerPCA(allData, nPCs = 10);
head(pcs)
# Out:
# Scaling data
# Doing PCA
# Using 10 PCs
# Doing tSNE
# sigma summary: Min. : 0.224546199294725 |1st Qu. : 0.333521684912082 |Median : 0.374315412519671 |Mean : 0.396648342569268 |3rd Qu. : 0.42914196826897 |Max. : 1.2562379484937 |
# Epoch: Iteration #100 error is: 19.2791410226917
# Epoch: Iteration #200 error is: 2.05229345269881
# Epoch: Iteration #300 error is: 1.76983001093214
# Epoch: Iteration #400 error is: 1.63868256348774
# Epoch: Iteration #500 error is: 1.580744182581
# Epoch: Iteration #600 error is: 1.54706861249921
# Epoch: Iteration #700 error is: 1.52467411721892
# Epoch: Iteration #800 error is: 1.50883263538204
# Epoch: Iteration #900 error is: 1.49695899559471
# Epoch: Iteration #1000 error is: 1.4880334427832

# %%
pcs$nPCs

# %%
end_time <- Sys.time()

# %%
end_time - start_time
# Out:
# Time difference of 1.632595 hours

# %%
df_out = t(pcs$x)[1:pcs$nPCs,]
dim(df_out)
df_out[1:5,1:5]

# %%
sum(colnames(df_out) == rownames(metadata))
# Out:
# [1] 5335

# %%
saveRDS(df_out, file = '../../output/feature_matrices/FM_BROCKMAN_10xpbmc5k.rds')

# %% [markdown]
# ### Downstream Analysis

# %%
# combine our sample description table with the tSNE projection
pcs$tSNEProj = merge(pcs$tSNEProj,metadata, by.x="ID",by.y="row.names")
pcs$tSNEProj$label = as.character(pcs$tSNEProj$label)
#pcs$tSNEProj$treated = !grepl("-rep",pcs$tSNEProj$celltype)

# %%
dim(pcs$tSNEProj)
head(pcs$tSNEProj)
# Out:
# [1] 5335    4
#   ID                 tSNE1     tSNE2     label
# 1 AAACGAAAGCGCAATG-1  84.13856 -66.80583 2
# 2 AAACGAAAGGGTATCG-1  47.28074 -80.58602 6
# 3 AAACGAAAGTAACATG-1 -64.35254  29.82407 1
# 4 AAACGAAAGTTACACC-1 -77.50753  56.25107 4
# 5 AAACGAACAGAGATGC-1  51.80038 -22.47216 5
# 6 AAACGAACATGCTATG-1  76.54333 -20.53941 6

# %%
options(repr.plot.width=6, repr.plot.height=4)
p=ggplot(pcs$tSNEProj, aes(x=tSNE1, y=tSNE2, colour=label)) + theme_classic() + geom_point(); 
print(p)
# Out:
# plot without title

# %%
sessionInfo()
# Out:
# R version 3.5.1 (2018-07-02)
# Platform: x86_64-conda_cos6-linux-gnu (64-bit)
# Running under: CentOS Linux 7 (Core)
#
# Matrix products: default
# BLAS: /data/pinello/SHARED_SOFTWARE/anaconda3/envs/ATACseq_BROCKMAN3/lib/R/lib/libRblas.so
# LAPACK: /data/pinello/SHARED_SOFTWARE/anaconda3/envs/ATACseq_BROCKMAN3/lib/R/lib/libRlapack.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] irlba_2.3.2          Matrix_1.2-17        BrockmanR_0.0.0.9000
# [4] tsne_0.1-3           ggplot2_3.2.0
#
# loaded via a namespace (and not attached):
#  [1] Rcpp_1.0.1       pillar_1.4.2     compiler_3.5.1   base64enc_0.1-3
#  [5] tools_3.5.1      zeallot_0.1.0    digest_0.6.20    uuid_0.1-2
#  [9] jsonlite_1.6     evaluate_0.14    tibble_2.1.3     gtable_0.3.0
# [13] lattice_0.20-38  pkgconfig_2.0.2  rlang_0.4.0      IRdisplay_0.7.0
# [17] IRkernel_1.0.1   repr_1.0.1       withr_2.1.2      dplyr_0.8.3
# [21] vctrs_0.2.0      grid_3.5.1       tidyselect_0.2.5 glue_1.3.1
# [25] R6_2.4.0         pbdZMQ_0.3-3     purrr_0.3.2      magrittr_1.5
# [29] backports_1.1.4  scales_1.0.0     htmltools_0.3.6  assertthat_0.2.1
# [33] colorspace_1.4-1 labeling_0.3     lazyeval_0.2.2   munsell_0.5.0
# [37] crayon_1.3.4

# %%
save.image(file = 'BROCKMAN_10xpbmc5k.RData')
